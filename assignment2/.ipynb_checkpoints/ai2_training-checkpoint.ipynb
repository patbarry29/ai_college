# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os

from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img
from tensorflow.keras.preprocessing import image_dataset_from_directory

from tensorflow.keras import Model
from tensorflow.keras import Input
from tensorflow.keras import Sequential
from tensorflow.keras.layers import RandomFlip
from tensorflow.keras.layers import RandomRotation
from tensorflow.keras.layers import RandomZoom
from tensorflow.keras.layers import RandomTranslation
from tensorflow.keras.layers import Rescaling
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras.models import load_model

from tensorflow.keras.optimizers import RMSprop

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# %% [markdown]
# <h1>Patrick Barry CA</h1>
# <p>My classifier will identify if a given image is a maple tree leaf or a horse-chestnut tree leaf.</p>
# <p>I chose these as have similar shapes generally, similar colours (other than red maple) but a human could easily differentiate between them.</p>
# <p>Let's see how a CNN will do.</p>

# %%
base_dir = "./"
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "val")
test_dir = os.path.join(base_dir, "test")

# %%
train_maple_dir = os.path.join(train_dir, "maple")
filenames_m = [os.path.join(train_maple_dir, filename) for filename in os.listdir(train_maple_dir)]
train_hc_dir = os.path.join(train_dir, "horse_chestnut")
filenames_hc = [os.path.join(train_hc_dir, filename) for filename in os.listdir(train_hc_dir)]

idx = 18 # Change this if you want to look at a different image
m_example = load_img(filenames_m[idx], target_size=(256,256))
hc_example = load_img(filenames_hc[idx], target_size=(256,256))
ax = plt.subplot(1, 2, 1)
plt.imshow(m_example)
plt.axis("off")
ax = plt.subplot(1, 2, 2)
plt.imshow(hc_example)
plt.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# Easy enough to distinguish between the 2. But will it be easy for a CNN?

# %% [markdown]
# <h2>Data Preprocessing</h2>
# <ul>
#     <li>Keras has the function: <code>image_dataset_from_directory</code>. There are many arguments to be considered but we only need to think about:
#         <ul>
#             <li><code>directory</code>: where the data is located.</li>
#             <li><code>label_mode</code>: We will use "binary",
#                 because we only have two classes (labels), which will be encoded as 0 or 1
#             </li>
#             <li><code>image_size</code>: Our dataset contains images of different sizes. The neural network
#                 can't work like this, so the images must all be resized to the same size. The default is
#                 $256 \times 256$. We shall investigate if this is the optimal size for our images.
#             </li>

# %%
# train_dataset = image_dataset_from_directory(directory=train_dir, label_mode="binary")
# val_dataset = image_dataset_from_directory(directory=val_dir, label_mode="binary")
# test_dataset = image_dataset_from_directory(directory=test_dir, label_mode="binary")

# %%
train_dataset = image_dataset_from_directory(directory=train_dir, label_mode="binary", image_size=(224, 224))
val_dataset = image_dataset_from_directory(directory=val_dir, label_mode="binary", image_size=(224, 224))
test_dataset = image_dataset_from_directory(directory=test_dir, label_mode="binary", image_size=(224, 224))
# Out:
# Found 100 files belonging to 2 classes.
# Metal device set to: Apple M1
# Found 48 files belonging to 2 classes.
# Found 50 files belonging to 2 classes.
# 2023-02-02 14:25:33.664063: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-02 14:25:33.664548: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# <h1>Pretrained Convolutional Neural Networks</h1>
# <ul>
#     <li>There are a number of pre-trained CNNs available in keras.</li>
#     <li>We will try:
#         <ul>
#             <li>VGG16</li>
#             <li>ResNet50</li>
#             <li>Inception V3</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h1>VGG16</h1>
# VGG16 is a CNN developed in Oxford in 2014 by Karen Simonyan and Andrew Zisserman. It comprises of 13 convolutional layers, 3 dense layers, and 5 max pooling layers. 16 layers with learnable paramaters, hence VGG16.

# %%
vgg16 = VGG16(weights="imagenet", include_top=True, input_shape=(224, 224, 3))

# %%
predictions = vgg16.predict(val_dataset)
decode_predictions(predictions, top=3)
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2023-02-02 14:25:36.446239: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-02 14:25:36.446834: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 1s 789ms/step
# [[('n12768682', 'buckeye', 0.8975326),
#   ('n03991062', 'pot', 0.0296391),
#   ('n12620546', 'hip', 0.020428322)],
#  [('n04136333', 'sarong', 0.14444973),
#   ('n03991062', 'pot', 0.079835415),
#   ('n12768682', 'buckeye', 0.05553498)],
#  [('n07745940', 'strawberry', 0.12361411),
#   ('n12267677', 'acorn', 0.06594704),
#   ('n03291819', 'envelope', 0.047889885)],
#  [('n07714571', 'head_cabbage', 0.22096223),
#   ('n13133613', 'ear', 0.17861262),
#   ('n04325704', 'stole', 0.06997936)],
#  [('n03991062', 'pot', 0.17814033),
#   ('n07714571', 'head_cabbage', 0.15917353),
#   ('n07745940', 'strawberry', 0.10701918)],
#  [('n04522168', 'vase', 0.40653694),
#   ('n03991062', 'pot', 0.13942732),
#   ('n07745940', 'strawberry', 0.061227903)],
#  [('n03188531', 'diaper', 0.14765623),
#   ('n01498041', 'stingray', 0.11360932),
#   ('n02869837', 'bonnet', 0.09873298)],
#  [('n03930313', 'picket_fence', 0.48443297),
#   ('n03991062', 'pot', 0.060282294),
#   ('n02206856', 'bee', 0.05735246)],
#  [('n03991062', 'pot', 0.048312083),
#   ('n04325704', 'stole', 0.037305757),
#   ('n04522168', 'vase', 0.037193555)],
#  [('n09256479', 'coral_reef', 0.43349963),
#   ('n01775062', 'wolf_spider', 0.09211502),
#   ('n03991062', 'pot', 0.0496918)],
#  [('n03598930', 'jigsaw_puzzle', 0.46412253),
#   ('n12267677', 'acorn', 0.41186124),
#   ('n03908714', 'pencil_sharpener', 0.03302092)],
#  [('n12768682', 'buckeye', 0.27617162),
#   ('n03457902', 'greenhouse', 0.19035704),
#   ('n03991062', 'pot', 0.13527164)],
#  [('n03991062', 'pot', 0.10067469),
#   ('n04136333', 'sarong', 0.08586761),
#   ('n04325704', 'stole', 0.060074136)],
#  [('n03958227', 'plastic_bag', 0.17411508),
#   ('n03944341', 'pinwheel', 0.16742614),
#   ('n04507155', 'umbrella', 0.07099126)],
#  [('n07768694', 'pomegranate', 0.26090977),
#   ('n12620546', 'hip', 0.22337832),
#   ('n13044778', 'earthstar', 0.06029337)],
#  [('n07753113', 'fig', 0.36223403),
#   ('n03991062', 'pot', 0.11169),
#   ('n07749582', 'lemon', 0.08929586)],
#  [('n03991062', 'pot', 0.141707),
#   ('n07714571', 'head_cabbage', 0.12912902),
#   ('n04522168', 'vase', 0.10030525)],
#  [('n12267677', 'acorn', 0.12156608),
#   ('n07714990', 'broccoli', 0.069853276),
#   ('n07715103', 'cauliflower', 0.029635053)],
#  [('n03991062', 'pot', 0.1589339),
#   ('n07745940', 'strawberry', 0.14903897),
#   ('n04522168', 'vase', 0.11122149)],
#  [('n04136333', 'sarong', 0.21927507),
#   ('n04209239', 'shower_curtain', 0.16478276),
#   ('n03534580', 'hoopskirt', 0.13332099)],
#  [('n03782006', 'monitor', 0.14481308),
#   ('n03991062', 'pot', 0.099458866),
#   ('n04152593', 'screen', 0.085935615)],
#  [('n03958227', 'plastic_bag', 0.5948728),
#   ('n03887697', 'paper_towel', 0.03507549),
#   ('n03188531', 'diaper', 0.031647157)],
#  [('n03930313', 'picket_fence', 0.5640135),
#   ('n02948072', 'candle', 0.069721565),
#   ('n04522168', 'vase', 0.04118805)],
#  [('n03782006', 'monitor', 0.58864754),
#   ('n01775062', 'wolf_spider', 0.119569436),
#   ('n04152593', 'screen', 0.10079421)],
#  [('n03782006', 'monitor', 0.61069393),
#   ('n03598930', 'jigsaw_puzzle', 0.18446468),
#   ('n04152593', 'screen', 0.025295565)],
#  [('n04371774', 'swing', 0.11219489),
#   ('n04589890', 'window_screen', 0.067035556),
#   ('n02480495', 'orangutan', 0.061389226)],
#  [('n12267677', 'acorn', 0.33632186),
#   ('n07714571', 'head_cabbage', 0.22807057),
#   ('n07715103', 'cauliflower', 0.12285628)],
#  [('n01824575', 'coucal', 0.09783407),
#   ('n01682714', 'American_chameleon', 0.0425959),
#   ('n02489166', 'proboscis_monkey', 0.040011846)],
#  [('n07730033', 'cardoon', 0.60717857),
#   ('n07718747', 'artichoke', 0.040235765),
#   ('n12267677', 'acorn', 0.029015047)],
#  [('n03944341', 'pinwheel', 0.14326368),
#   ('n03958227', 'plastic_bag', 0.11529017),
#   ('n07714571', 'head_cabbage', 0.046065655)],
#  [('n07714571', 'head_cabbage', 0.21318938),
#   ('n04033901', 'quill', 0.10377453),
#   ('n03958227', 'plastic_bag', 0.08734826)],
#  [('n04136333', 'sarong', 0.34362343),
#   ('n03958227', 'plastic_bag', 0.09108128),
#   ('n03534580', 'hoopskirt', 0.059934035)],
#  [('n12267677', 'acorn', 0.28587845),
#   ('n02280649', 'cabbage_butterfly', 0.1608419),
#   ('n07714571', 'head_cabbage', 0.08084384)],
#  [('n03598930', 'jigsaw_puzzle', 0.05959362),
#   ('n03991062', 'pot', 0.048371892),
#   ('n02843684', 'birdhouse', 0.04118973)],
#  [('n07714571', 'head_cabbage', 0.23087466),
#   ('n03958227', 'plastic_bag', 0.18939863),
#   ('n07749582', 'lemon', 0.115844205)],
#  [('n03958227', 'plastic_bag', 0.7207582),
#   ('n03887697', 'paper_towel', 0.03455443),
#   ('n03788365', 'mosquito_net', 0.024345392)],
#  [('n07714571', 'head_cabbage', 0.5060136),
#   ('n07715103', 'cauliflower', 0.22377917),
#   ('n03958227', 'plastic_bag', 0.09272509)],
#  [('n03944341', 'pinwheel', 0.24085246),
#   ('n07753275', 'pineapple', 0.21874845),
#   ('n07730033', 'cardoon', 0.072877675)],
#  [('n12267677', 'acorn', 0.48575872),
#   ('n07714990', 'broccoli', 0.06022356),
#   ('n07715103', 'cauliflower', 0.05086505)],
#  [('n03476684', 'hair_slide', 0.28127882),
#   ('n03991062', 'pot', 0.15563732),
#   ('n06359193', 'web_site', 0.07013749)],
#  [('n03325584', 'feather_boa', 0.44868383),
#   ('n03930313', 'picket_fence', 0.058437187),
#   ('n09256479', 'coral_reef', 0.04845459)],
#  [('n02840245', 'binder', 0.13134016),
#   ('n04476259', 'tray', 0.11456467),
#   ('n03347037', 'fire_screen', 0.11031056)],
#  [('n03887697', 'paper_towel', 0.14949596),
#   ('n03291819', 'envelope', 0.07513244),
#   ('n03944341', 'pinwheel', 0.07104474)],
#  [('n03991062', 'pot', 0.30476272),
#   ('n04522168', 'vase', 0.29807505),
#   ('n03485794', 'handkerchief', 0.122485474)],
#  [('n03782006', 'monitor', 0.3976674),
#   ('n04152593', 'screen', 0.16761696),
#   ('n04404412', 'television', 0.111285485)],
#  [('n01820546', 'lorikeet', 0.15345155),
#   ('n07730033', 'cardoon', 0.08322259),
#   ('n01833805', 'hummingbird', 0.047070205)],
#  [('n03782006', 'monitor', 0.35681778),
#   ('n04152593', 'screen', 0.13590409),
#   ('n04404412', 'television', 0.08963308)],
#  [('n06359193', 'web_site', 0.26529062),
#   ('n03291819', 'envelope', 0.08586014),
#   ('n04522168', 'vase', 0.069990344)]]

# %% [markdown]
# Here is the point where I could experiment with image size, switching all 224s to 256s. However, it already takes long enough to run the notebook without the experiments, so my conclusion is that 224 is optimal.

# %%
vgg16_base = VGG16(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# %%
inputs = Input(shape=(224, 224, 3))
x = preprocess_input(inputs)
x = vgg16_base(x)
x = Flatten()(x)
outputs = Dense(1, activation="sigmoid")(x)
vgg16_model = Model(inputs=inputs, outputs=outputs)

# %%
vgg16_base.trainable = False

# %%
vgg16_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
vgg16_model_history = vgg16_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:25:38.573869: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:25:41.407587: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(vgg16_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = vgg16_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 286ms/step - loss: 1.7500 - accuracy: 0.9167
# 0.9166666865348816

# %% [markdown]
# The weights are currently fixed, so we shall change that and see if it improves our score.
# No batch normalization layers, so we can make all layers trainable.

# %%
vgg16_base.trainable = True

# %%
vgg16_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
vgg16_model_history = vgg16_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:27:16.581853: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:27:25.281870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(vgg16_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = vgg16_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 284ms/step - loss: 14.2380 - accuracy: 0.5000
# 0.5

# %% [markdown]
# This model is much worse when the base layers are made trainable so we shall reset back to not trainable.

# %%
vgg16_base.trainable = False

# %%
vgg16_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# <p>VGG16 is definitely a network we can consider, it seems to get high accuracy on our dataset, but it isn't always consistent.</p>
# <p>On one run through, it may get a considerably high accuracy, while on the next, it will be much lower.
# Because of this instability, let's investigate some other CNNs available to us.</p>

# %% [markdown]
# <h1>Inception V3</h1>

# %%
inception_base = InceptionV3(weights="imagenet", include_top=False, input_shape=(224,224, 3))

# %%
inputs = Input(shape=(224, 224, 3))
x = preprocess_input(inputs)
x = inception_base(x)
x = Flatten()(x)
outputs = Dense(1, activation="sigmoid")(x)
inception_model = Model(inputs=inputs, outputs=outputs)

# %%
inception_base.trainable = False

# %%
inception_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_1 (Dense)             (None, 1)                 51201
#
# =================================================================
# Total params: 21,853,985
# Trainable params: 51,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
inception_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
inception_model_history = inception_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:31:31.881258: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:31:35.200068: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(inception_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = inception_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 0s 101ms/step - loss: 86.7361 - accuracy: 0.7083
# 0.7083333730697632

# %% [markdown]
# <p>We will try making the base trainable, but here we must not allow the batch normalization layers to be trainable.</p>
# <p>From the above graph, it looks like the learning rate is too high. Let's also reduce that a little.</p>

# %%
for layer in inception_base.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False
    else:
        layer.trainable = True

# %%
inception_model.compile(optimizer=RMSprop(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

# %%
inception_model_history = inception_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:31:54.617865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:31:58.392582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(inception_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = inception_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 0s 99ms/step - loss: 90.9068 - accuracy: 0.6667
# 0.6666666865348816

# %% [markdown]
# <p>Reducing the learning rate has certainly improved the training.</p>
# <p>However, the Inception network produces lower accuracy on average than VGG16, so we need not consider this model.

# %% [markdown]
# <h1>ResNet50</h1>

# %%
rn50_base = ResNet50(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# %%
inputs = Input(shape=(224, 224, 3))
x = preprocess_input(inputs)
x = rn50_base(x)
x = Flatten()(x)
outputs = Dense(1, activation="sigmoid")(x)
rn50_model = Model(inputs=inputs, outputs=outputs)

# %%
rn50_base.trainable = False

# %%
rn50_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
rn50_model_history = rn50_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:32:17.109312: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:32:21.444886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(rn50_model_history.history).plot(ylim=(-0.5, 15))
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = rn50_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 179ms/step - loss: 6.2787 - accuracy: 0.9167
# 0.9166666865348816

# %% [markdown]
# <p>This is a very strange sight to see the validation loss remaining constantly high but the validation accuracy is also one of the highest we've seen so far.</p>
# <p>Let's see if making it trainable has any effect.</p>

# %%
for layer in rn50_base.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = False
    else:
        layer.trainable = True

# %%
rn50_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
rn50_model_history = rn50_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# 2023-02-02 14:33:33.752833: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:33:38.034788: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(rn50_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = rn50_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 180ms/step - loss: 15.1266 - accuracy: 0.8958
# 0.8958333730697632

# %% [markdown]
# <p>The accuracy is very high (de-high-de-high-de-high), but the validation loss is also still very high (de-high-de-high-de-ho) which indicates the network is overfitting.</p>
# <p>Despite this potential overfitting problem, this network is the most consistent at producing high accuracy, so we will use this network from now on. Let's try something to fix the overfitting.</p>

# %% [markdown]
# <h1>Data Augmentation</h1>
# <p>An obvious way to reduce overfitting is to add more examples.</p>

# %%
inputs = Input(shape=(224, 224, 3))
x = RandomFlip(mode="horizontal")(inputs)
x = RandomRotation(factor=0.1)(x)
x = RandomZoom(height_factor=(-0.2, 0.2))(x)
x = RandomTranslation(height_factor=0.2, width_factor=0.2)(x)
x = preprocess_input(x)
x = rn50_base(x)
x = Flatten()(x)
outputs = Dense(1, activation="sigmoid")(x)
augmented_rn50_model = Model(inputs=inputs, outputs=outputs)

# %%
augmented_rn50_model.compile(optimizer=RMSprop(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# %%
augmented_rn50_model_history = augmented_rn50_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-02-02 14:34:00.375372: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:34:07.662091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# Let's see of the val loss has changed.
pd.DataFrame(augmented_rn50_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# <p>Well , the validation loss has certainly changed, it's no longer constantly around 10, but jumps around quite a bit, ending up below 10.</p>

# %%
val_loss, val_acc = augmented_rn50_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 178ms/step - loss: 7.4987 - accuracy: 0.9375
# 0.9375

# %% [markdown]
# <p>Data augmentation hasn't had a negative effect on the accuracy of the network, so we shall continue using it.</p>
# <p>However, both loss values are now fluctuating up and down, so let's try remedy that.</p>

# %% [markdown]
# <h1>Tweaking Settings</h1>

# %% [markdown]
# Let's try decreasing the learning rate.

# %%
augmented_rn50_model.compile(optimizer=RMSprop(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

# %%
augmented_rn50_model_history = augmented_rn50_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-02-02 14:34:54.070461: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:35:01.477273: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# Let's see of the val loss has changed.
pd.DataFrame(augmented_rn50_model_history.history).plot()
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = augmented_rn50_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 211ms/step - loss: 6.8507 - accuracy: 0.9167
# 0.9166666865348816

# %% [markdown]
# Loss is still fluctuating quite a bit, but this is likely due to the nature of feeding in mini-batches. One could be rather easy to predict, with the next being much different, causing the loss to increase.

# %% [markdown]
# Let's try another hidden dense layer to our network.

# %%
inputs = Input(shape=(224, 224, 3))
x = RandomFlip(mode="horizontal")(inputs)
x = RandomRotation(factor=0.1)(x)
x = RandomZoom(height_factor=(-0.2, 0.2))(x)
x = RandomTranslation(height_factor=0.2, width_factor=0.2)(x)
x = preprocess_input(x)
x = rn50_base(x)
x = Flatten()(x)
x = Dense(512, activation="relu")(x)
outputs = Dense(1, activation="sigmoid")(x)
dense_augmented_rn50_model = Model(inputs=inputs, outputs=outputs)

# %%
dense_augmented_rn50_model.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])

# %%
dense_augmented_rn50_model_history = dense_augmented_rn50_model.fit(train_dataset, epochs=30, 
                validation_data=val_dataset, 
                callbacks=[EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True)],
                verbose=0)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-02-02 14:35:39.308658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-02-02 14:35:48.914386: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
pd.DataFrame(dense_augmented_rn50_model_history.history).plot(ylim=(-0.05, 5))
# Out:
# <AxesSubplot: >

# %%
val_loss, val_acc = dense_augmented_rn50_model.evaluate(val_dataset)
val_acc
# Out:
# 2/2 [==============================] - 1s 198ms/step - loss: 0.3919 - accuracy: 0.9375
# 0.9375

# %% [markdown]
# This seems to have significantly decreased the loss values and increased the accuracy, so let's save this model.

# %% [markdown]
# <h1>Best Model</h1>

# %%
dense_augmented_rn50_model.save("best_network.h5")
